# %% [markdown]
# ## ==========================================================
# ## 🧠 Hopify SaaS: Churn KPI Summary Table
# ## ==========================================================

# %%
import os
import pandas as pd

# ================================
# 📁 Set Base Path to Project Root
# ================================

try:
    BASE_PATH = os.path.abspath(os.path.join(os.path.dirname(__file__), "..", "..", ".."))
except NameError:
    # Jupyter or interactive context
    BASE_PATH = os.path.abspath(os.path.join(os.getcwd(), "..", "..", ".."))

print("📁 Base path set to:", BASE_PATH)

# ================================
# 📄 Load Churn Data CSV
# ================================

file_path = os.path.join(BASE_PATH, "03_data", "churn_summary_by_segment.csv")

churn_df = pd.read_csv(file_path)
print("✅ File loaded successfully!")
print(churn_df.columns.to_list())
# Out:
# ✅ File loaded successfully!
# ['Month', 'Segment', 'Churned Customers', 'Active Customers', 'Churn Rate %', 'Retention %', 'Benchmark %', 'Variance %', 'Avg. Support Tickets', 'Avg. Resolution Days']

# %% [markdown]
# ## ================================
# ## 📊 Churn Summary KPI Calculator
# ## ================================

# %%
# ================================
# 📊 Churn Summary KPI Calculator
# ================================

kpi_table = churn_df.groupby('Segment').agg({
    'Churn Rate %': ['mean', lambda x: x.iloc[-1]],
    'Benchmark %': 'first'  # ← correct column name from your CSV
}).reset_index()

kpi_table.columns = [
    'Segment',
    'Avg Actual Churn (%)',
    'Most Recent Churn (%)',
    'Benchmark Churn Rate (%)'
]

kpi_table['Variance to Benchmark'] = (
    kpi_table['Most Recent Churn (%)'] - kpi_table['Benchmark Churn Rate (%)']
)

# %% [markdown]
# ## =================================
# ## 🎨 Format KPI Metrics for Display
# ## =================================

# %%
kpi_table['Avg Actual Churn (%)'] = kpi_table['Avg Actual Churn (%)'].apply(lambda x: f"{x:.2%}")
kpi_table['Most Recent Churn (%)'] = kpi_table['Most Recent Churn (%)'].apply(lambda x: f"{x:.2%}")
kpi_table['Benchmark Churn Rate (%)'] = kpi_table['Benchmark Churn Rate (%)'].apply(lambda x: f"{x:.2%}")
kpi_table['Variance to Benchmark'] = kpi_table['Variance to Benchmark'].apply(lambda x: f"{x:+.2f} pts")

# %% [markdown]
# ## ================================
# ## 💾 Optional: Export KPI Table
# ## ================================

# %%
# output_path = os.path.join(
#     BASE_DIR,
#     "01_project_artifacts",
#     "02_sql_output",
#     "01_project_churn_retention_analysis",
#     "01-hopify-churn-kpis.csv"
# )
# kpi_table.to_csv(output_path, index=False)

# %% [markdown]
# ## ================================
# ## ✅ Preview
# ## ================================

# %%
print("\n📌 Churn KPI Summary Table:\n")
print(kpi_table)
# Out:
# 📌 Churn KPI Summary Table:
#
#       Segment Avg Actual Churn (%) Most Recent Churn (%)  \
# 0  Enterprise              169.00%               169.00%
# 1  Mid-Market              111.00%               111.00%
# 2         SMB              270.00%               270.00%
#
#   Benchmark Churn Rate (%) Variance to Benchmark
# 0                   75.00%             +0.94 pts
# 1                  200.00%             -0.89 pts
# 2                  400.00%             -1.30 pts
